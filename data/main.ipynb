# %%
import pandas as pd

data = pd.read_csv('data.csv').head()

purchases = data[data["purchase_quantity"] > 0]
purchases.head(10)
# Out:
#    item_id    name     category  price  stock               description  \
# 0        1  Item A         Food   9.99   1000          Premium pet food
# 1        2  Item B         Toys   5.99    500  Interactive toy for pets
# 2        3  Item C  Accessories  12.99    300       Pet collar for dogs
# 3        4  Item D         Food   7.49    750          Healthy cat food
#
#            manufacturer  weight                       image_url  client_id  \
# 0         ABC Pet Foods     2.0  https://example.com/item-a.jpg  client123
# 1           Pet Fun Co.     0.5  https://example.com/item-b.jpg  client123
# 2  Pet Accessories Inc.     0.2  https://example.com/item-c.jpg  client456
# 3     Healthy Pets Ltd.     1.5  https://example.com/item-d.jpg  client789
#
#     client_name             client_email         purchase_date  \
# 0      John Doe      johndoe@example.com  2023-09-01T10:30:00Z
# 1      John Doe      johndoe@example.com  2023-09-03T15:45:00Z
# ...
